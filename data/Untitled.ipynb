# %%
import pandas as pd

# %%
data = pd.read_csv('TADPOLE_D1_D2.csv')
# Out:
# /Users/aidenarnold/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (471,473,474,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,521,522,523,524,525,526,527,528,529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552,553,554,555,556,557,558,559,560,561,562,563,569,570,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,594,595,596,597,599,601,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,624,625,626,627,628,629,630,631,632,633,634,636,637,638,639,640,641,642,643,644,645,646,647,648,649,650,651,652,653,654,655,656,657,658,659,660,661,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,707,708,709,710,711,712,713,714,715,716,717,718,71
# ...

# %%
data.shape
# Out:
# (12741, 1907)

# %%
data.tail(20)
# Out:
#         RID        PTID VISCODE  SITE  D1  D2 COLPROT ORIGPROT    EXAMDATE  \
# 12721  2213  127_S_2213     m72   127   1   1   ADNI2   ADNIGO  2016-12-08
# 12722  2234  127_S_2234     m72   127   1   1   ADNI2   ADNIGO  2016-12-09
# 12723  4205  099_S_4205     m60    99   1   1   ADNI2    ADNI2  2016-12-08
# 12724  4356  135_S_4356     m60   135   1   1   ADNI2    ADNI2  2016-12-12
# 12725   555  035_S_0555    m120    35   1   1   ADNI2    ADNI1  2016-12-14
# 12726  1023  036_S_1023    m108    36   1   1   ADNI2    ADNI1  2017-01-10
# 12727  5263  032_S_5263     m24    32   1   0   ADNI2    ADNI2  2017-01-17
# 12728  1032  127_S_1032    m120   127   1   1   ADNI2    ADNI1  2016-11-30
# 12729  4287  129_S_4287     m60   129   1   1   ADNI2    ADNI2  2016-10-28
# 12730   296  100_S_0296    m120   100   1   1   ADNI2    ADNI1  2017-01-24
# 12731  1286  100_S_1286    m108   100   1   1   ADNI2    ADNI1  2017-01-25
# ...

# %%
d.loc[0:20, ['D1', 'D2', 'VISCODE', 'EXAMDATE', 'Ventricles', 'Ventricles_bl', 'sum']]
# Out:
#     D1  D2 VISCODE    EXAMDATE  Ventricles  Ventricles_bl  sum
# 0    1   1      bl  2005-09-08    118233.0       118233.0  NaN
# 1    1   0      bl  2005-09-12     84599.0        84599.0  NaN
# 2    1   0     m06  2006-03-13     88580.0        84599.0  NaN
# 3    1   0     m12  2006-09-12     90099.0        84599.0  NaN
# 4    1   0     m24  2007-09-12     97420.0        84599.0  NaN
# 5    1   0      bl  2005-11-08     39605.0        39605.0  NaN
# 6    1   0     m06  2006-05-02     39726.0        39605.0  NaN
# 7    1   0     m12  2006-11-14     38527.0        39605.0  NaN
# 8    1   0     m18  2007-05-14     40768.0        39605.0  NaN
# 9    1   0     m36  2008-11-18     45254.0        39605.0  NaN
# 10   1   0      bl  2005-09-07     34062.0        34062.0  NaN
# 11   1   0     m06  2006-03-09     34119.0        34062.0  NaN
# 12   1   0     m12  2006-09-05     35333.0        34062.0  NaN
# 13   1   0     m24  2007-09-07     37853.0        34062.0  NaN
# ...

# %%
ventricles = ['ST127SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST30SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST37SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST89SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST8SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST96SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16',
              'ST9SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16']

# %%
data[ventricles]
# Out:
#       ST127SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16  \
# 0                                            3644
# 1                                            3155
# 2                                            3036
# 3                                            2981
# 4                                            3252
# 5                                            1336
# 6                                            1480
# 7                                            1384
# 8                                            1431
# 9                                            1617
# 10                                           1548
# 11                                           1493
# 12                                           1565
# 13                                           1791
# 14                                           1757
# 15                                           2651
# 16                                           2663
# 17                                           2658
# ...

# %%
data['ST8SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16'] = pd.to_numeric(data['ST8SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16'], errors='coerce')

# %%
data['ST8SV_UCSFFSX_11_02_15_UCSFFSX51_08_01_16']
# Out:
# 0        24.0
# 1        93.0
# 2        29.0
# 3        81.0
# 4        80.0
# 5         NaN
# 6         1.0
# 7         NaN
# 8         NaN
# 9         NaN
# 10        7.0
# 11        6.0
# 12        NaN
# 13       15.0
# 14       19.0
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        5.0
# 23        6.0
# 24       20.0
# 25       23.0
# 26       58.0
# 27       15.0
# 28        NaN
# 29       21.0
#          ...
# 12711     NaN
# 12712     NaN
# 12713     NaN
# 12714     NaN
# 12715     NaN
# 12716     NaN
# 12717     NaN
# 12718     NaN
# 12719     NaN
# 12720     NaN
# 12721     NaN
# 12722     NaN
# 12723     NaN
# 12724     NaN
# 12725     NaN
# 12726     NaN
# 12727     NaN
# 12728     NaN
# 12729     NaN
# 12730     NaN
# 12731     NaN
# 12732     NaN
# 12733     NaN
# 12734     NaN
# 12735     NaN
# 12736     NaN
# 12737     NaN
# 12738     NaN
# 12739     NaN
# 12740     NaN
# ...

# %%
d['sum']
# Out:
# 0     3644
# 1     3155
# 2     3036
# 3     2981
# 4     3252
# 5     1336
# 6     1480
# 7     1384
# 8     1431
# 9     1617
# 10    1548
# 11    1493
# 12    1565
# 13    1791
# 14    1757
# 15    2651
# 16    2663
# 17    2658
# 18    2674
# 19    2840
# 20    1771
# Name: sum, dtype: object
